# %% [markdown]
# <a href="https://colab.research.google.com/github/iacchus/0h-my-c0l4b/blob/main/pynacl-000-generate-key-pair.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pynacl

# %%
import requests
from nacl.signing import SigningKey

# %%
private_key = SigningKey.generate()

# %%
private_key

# %%
public_key_hex = private_key.verify_key.encode().hex()

# %%
public_key_hex
# Out:
# 'ee8e065e920b60979ec4ace878a0fd2027a55416cb544bb59a679d7b8a8dbb40'
